# %%
import imageio.v2 as imageio
import numpy as np
import matplotlib.pyplot as plt

# Carregando a imagem
imagem = imageio.imread('Martinha.jpeg')

# Convertendo para tons de cinza
def tons_de_cinza(imagem):
    tons_de_cinza = np.dot(image[..., :3], [0.299, 0.587, 0.114])
    return np.clip(tons_de_cinza, 0, 255).astype(np.uint8)

# Binarizando a imagem
def binario(imagem, threshold=128):
    binario = (imagem > threshold) * 255
    return binario.astype(np.uint8)

img_tons_de_cinza = tons_de_cinza(image)
img_binario = to_binary(img_tons_de_cinza)

imageio.imwrite('Tons de cinza.jpg', img_tons_de_cinza)
imageio.imwrite('Imagem binária.jpg', binary_image)

# Visualizando as imagens no Colab
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.imshow(imagem)
plt.title('Imagem Original')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(img_tons_de_cinza, cmap='gray')
plt.title('Imagem em Cinza')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(binary_image, cmap='gray')
plt.title('Imagem Binária')
plt.axis('off')

plt.show()
